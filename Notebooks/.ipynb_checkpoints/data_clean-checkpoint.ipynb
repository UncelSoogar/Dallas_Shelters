# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
#Loop through csvs and append to df
years = ["2015", "2016", "2017", "2018", "2019", "2020"]
df = pd.DataFrame()
for year in years:
    temp = pd.read_csv(f"../Resources/FY_{year}_Dallas_Animal_Shelter_Data.csv")
    df = df.append(temp, ignore_index = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211216 entries, 0 to 211215
# Data columns (total 34 columns):
# Activity Number           88665 non-null object
# Activity Sequence         211216 non-null int64
# Additional Information    103130 non-null object
# Animal Breed              211215 non-null object
# Animal Id                 211216 non-null object
# Animal Origin             207986 non-null object
# Animal Type               211215 non-null object
# Census Tract              202431 non-null object
# Chip Status               208083 non-null object
# Council District          202431 non-null object
# Due Out                   211216 non-null object
# Hold Request              118748 non-null object
# Impound Number            211216 non-null object
# Intake Condition          211216 non-null object
# Intake Date               211216 non-null object
# Intake Subtype            206683 non-null object
# Intake Time               211216 non-null object
# Intake Total              176397 non-null float64
# Intake Type               211216 non-null object
# Kennel Number             211216 non-null object
# Kennel Status             211216 non-null object
# Month                     211216 non-null object
# Outcome Condition         204342 non-null object
# Outcome Date              210594 non-null object
# Outcome Subtype           113647 non-null object
# Outcome Time              211216 non-null object
# Outcome Type              211216 non-null object
# Reason                    79876 non-null object
# Receipt Number            85771 non-null object
# Service Request Number    9671 non-null object
# Source Id                 211216 non-null object
# Staff Id                  211216 non-null object
# Tag Type                  2 non-null object
# Year                      211216 non-null object
# dtypes: float64(1), int64(1), object(32)
# memory usage: 54.8+ MB

# %%
df.head()
# Out:
#   Activity Number  Activity Sequence Additional Information   Animal Breed  \
# 0             NaN                  1                ADOPTED    DOMESTIC SH
# 1             NaN                  1                    NaN  LABRADOR RETR
# 2             NaN                  1                    NaN  GERM SHEPHERD
# 3             NaN                  1          VOMIT 5X 9/20    DOMESTIC SH
# 4             NaN                  1                    NaN     ROTTWEILER
#
#   Animal Id     Animal Origin Animal Type Census Tract   Chip Status  \
# 0  A0000575  OVER THE COUNTER         CAT            W  SCAN NO CHIP
# 1  A0008962             FIELD         DOG        75218  SCAN NO CHIP
# 2  A0121376             FIELD         DOG          39A     SCAN CHIP
# 3  A0129114  OVER THE COUNTER         CAT        75243     SCAN CHIP
# 4  A0157434             FIELD         DOG          38G  SCAN NO CHIP
#
#   Council District                 Due Out              Hold Request  \
# 0                W  10/06/2014 12:00:00 AM                  ADOPTION
# 1               18  10/03/2015 12:00:00 AM                       NaN
# 2               9A  05/02/2015 12:00:00 AM                       NaN
# 3               43  09/22/2015 12:00:00 AM  EVERYDAY ADOPTION CENTER
# 4               8G  12/03/2014 12:00:00 AM                       NaN
#
#   Impound Number                        Intake Condition  \
# 0     K14-297573  TREATABLE REHABILITABLE NON-CONTAGIOUS
# 1     K15-328347  TREATABLE REHABILITABLE NON-CONTAGIOUS
# 2     K15-314218     TREATABLE MANAGEABLE NON-CONTAGIOUS
# 3     K15-327996  TREATABLE REHABILITABLE NON-CONTAGIOUS
# 4     K14-302641    UNHEALTHY UNTREATABLE NON-CONTAGIOUS
#
#               Intake Date     Intake Subtype             Intake Time  \
# 0  10/02/2014 12:00:00 AM           CONFINED  12/31/1899 11:56:00 AM
# 1  09/24/2015 12:00:00 AM          KEEP SAFE  12/31/1899 03:50:00 PM
# 2  05/01/2015 12:00:00 AM           CONFINED  12/31/1899 12:09:00 PM
# 3  09/19/2015 12:00:00 AM            GENERAL  12/31/1899 04:46:00 PM
# 4  12/03/2014 12:00:00 AM  - DEAD ON ARRIVAL  12/31/1899 08:06:00 PM
#
#    Intake Total      Intake Type Kennel Number Kennel Status     Month  \
# 0           1.0            STRAY        AC 035   UNAVAILABLE  OCT.2014
# 1           1.0      CONFISCATED       LFD 088           LAB  SEP.2015
# 2           1.0            STRAY       LFD 042           LAB  MAY.2015
# 3           1.0  OWNER SURRENDER      PSCAT 11   UNAVAILABLE  SEP.2015
# 4           1.0  OWNER SURRENDER       FREEZER   UNAVAILABLE  DEC.2014
#
#                         Outcome Condition            Outcome Date  \
# 0  TREATABLE REHABILITABLE NON-CONTAGIOUS  10/12/2014 12:00:00 AM
# 1     TREATABLE MANAGEABLE NON-CONTAGIOUS  10/04/2015 12:00:00 AM
# 2     TREATABLE MANAGEABLE NON-CONTAGIOUS  05/03/2015 12:00:00 AM
# 3  TREATABLE REHABILITABLE NON-CONTAGIOUS  10/26/2015 12:00:00 AM
# 4    UNHEALTHY UNTREATABLE NON-CONTAGIOUS  12/04/2014 12:00:00 AM
#
#   Outcome Subtype            Outcome Time     Outcome Type    Reason  \
# 0             NaN  12/31/1899 03:25:00 PM         ADOPTION       NaN
# 1             NaN  12/31/1899 12:22:00 PM       EUTHANIZED       NaN
# 2             NaN  12/31/1899 11:53:00 AM       EUTHANIZED       NaN
# 3             NaN  12/31/1899 02:09:00 PM         ADOPTION  ALLERGIC
# 4             NaN  12/31/1899 12:00:00 PM  DEAD ON ARRIVAL       NaN
#
#   Receipt Number Service Request Number Source Id Staff Id Tag Type    Year
# 0     R14-372380                    NaN  P0671044       SN      NaN  FY2015
# 1            NaN                 442631  P0053980       MB      NaN  FY2015
# 2            NaN                    NaN  P0661191       MB      NaN  FY2015
# 3     R15-425259                    NaN  P0055049   CBM/JS      NaN  FY2015
# 4            NaN                    NaN  P0093154       DD      NaN  FY2015

# %%
#Create df with useful columns

clean_df = df[['Animal Id', 'Animal Type', 'Animal Breed', 'Animal Origin', 'Census Tract',
              'Council District', 'Chip Status', 'Intake Date', 'Outcome Date',
              'Intake Condition', 'Outcome Condition', 'Reason', 'Outcome Type', 'Additional Information']]
clean_df.head()
# Out:
#   Animal Id Animal Type   Animal Breed     Animal Origin Census Tract  \
# 0  A0000575         CAT    DOMESTIC SH  OVER THE COUNTER            W
# 1  A0008962         DOG  LABRADOR RETR             FIELD        75218
# 2  A0121376         DOG  GERM SHEPHERD             FIELD          39A
# 3  A0129114         CAT    DOMESTIC SH  OVER THE COUNTER        75243
# 4  A0157434         DOG     ROTTWEILER             FIELD          38G
#
#   Council District   Chip Status             Intake Date  \
# 0                W  SCAN NO CHIP  10/02/2014 12:00:00 AM
# 1               18  SCAN NO CHIP  09/24/2015 12:00:00 AM
# 2               9A     SCAN CHIP  05/01/2015 12:00:00 AM
# 3               43     SCAN CHIP  09/19/2015 12:00:00 AM
# 4               8G  SCAN NO CHIP  12/03/2014 12:00:00 AM
#
#              Outcome Date                        Intake Condition  \
# 0  10/12/2014 12:00:00 AM  TREATABLE REHABILITABLE NON-CONTAGIOUS
# 1  10/04/2015 12:00:00 AM  TREATABLE REHABILITABLE NON-CONTAGIOUS
# 2  05/03/2015 12:00:00 AM     TREATABLE MANAGEABLE NON-CONTAGIOUS
# 3  10/26/2015 12:00:00 AM  TREATABLE REHABILITABLE NON-CONTAGIOUS
# 4  12/04/2014 12:00:00 AM    UNHEALTHY UNTREATABLE NON-CONTAGIOUS
#
#                         Outcome Condition    Reason     Outcome Type  \
# 0  TREATABLE REHABILITABLE NON-CONTAGIOUS       NaN         ADOPTION
# 1     TREATABLE MANAGEABLE NON-CONTAGIOUS       NaN       EUTHANIZED
# 2     TREATABLE MANAGEABLE NON-CONTAGIOUS       NaN       EUTHANIZED
# 3  TREATABLE REHABILITABLE NON-CONTAGIOUS  ALLERGIC         ADOPTION
# 4    UNHEALTHY UNTREATABLE NON-CONTAGIOUS       NaN  DEAD ON ARRIVAL
#
#   Additional Information
# 0                ADOPTED
# 1                    NaN
# 2                    NaN
# 3          VOMIT 5X 9/20
# 4                    NaN

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211216 entries, 0 to 211215
# Data columns (total 14 columns):
# Animal Id                 211216 non-null object
# Animal Type               211215 non-null object
# Animal Breed              211215 non-null object
# Animal Origin             207986 non-null object
# Census Tract              202431 non-null object
# Council District          202431 non-null object
# Chip Status               208083 non-null object
# Intake Date               211216 non-null object
# Outcome Date              210594 non-null object
# Intake Condition          211216 non-null object
# Outcome Condition         204342 non-null object
# Reason                    79876 non-null object
# Outcome Type              211216 non-null object
# Additional Information    103130 non-null object
# dtypes: object(14)
# memory usage: 22.6+ MB

# %%
#Change obj to datetime
clean_df['Intake Date'] = pd.to_datetime(clean_df['Intake Date'])
clean_df['Outcome Date'] = pd.to_datetime(clean_df['Outcome Date'])
# Out:
# C:\Users\slapp\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\slapp\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211216 entries, 0 to 211215
# Data columns (total 14 columns):
# Animal Id                 211216 non-null object
# Animal Type               211215 non-null object
# Animal Breed              211215 non-null object
# Animal Origin             207986 non-null object
# Census Tract              202431 non-null object
# Council District          202431 non-null object
# Chip Status               208083 non-null object
# Intake Date               211216 non-null datetime64[ns]
# Outcome Date              210594 non-null datetime64[ns]
# Intake Condition          211216 non-null object
# Outcome Condition         204342 non-null object
# Reason                    79876 non-null object
# Outcome Type              211216 non-null object
# Additional Information    103130 non-null object
# dtypes: datetime64[ns](2), object(12)
# memory usage: 22.6+ MB

# %%
clean_df.head()
# Out:
#   Animal Id Animal Type   Animal Breed     Animal Origin Census Tract  \
# 0  A0000575         CAT    DOMESTIC SH  OVER THE COUNTER            W
# 1  A0008962         DOG  LABRADOR RETR             FIELD        75218
# 2  A0121376         DOG  GERM SHEPHERD             FIELD          39A
# 3  A0129114         CAT    DOMESTIC SH  OVER THE COUNTER        75243
# 4  A0157434         DOG     ROTTWEILER             FIELD          38G
#
#   Council District   Chip Status Intake Date Outcome Date  \
# 0                W  SCAN NO CHIP  2014-10-02   2014-10-12
# 1               18  SCAN NO CHIP  2015-09-24   2015-10-04
# 2               9A     SCAN CHIP  2015-05-01   2015-05-03
# 3               43     SCAN CHIP  2015-09-19   2015-10-26
# 4               8G  SCAN NO CHIP  2014-12-03   2014-12-04
#
#                          Intake Condition  \
# 0  TREATABLE REHABILITABLE NON-CONTAGIOUS
# 1  TREATABLE REHABILITABLE NON-CONTAGIOUS
# 2     TREATABLE MANAGEABLE NON-CONTAGIOUS
# 3  TREATABLE REHABILITABLE NON-CONTAGIOUS
# 4    UNHEALTHY UNTREATABLE NON-CONTAGIOUS
#
#                         Outcome Condition    Reason     Outcome Type  \
# 0  TREATABLE REHABILITABLE NON-CONTAGIOUS       NaN         ADOPTION
# 1     TREATABLE MANAGEABLE NON-CONTAGIOUS       NaN       EUTHANIZED
# 2     TREATABLE MANAGEABLE NON-CONTAGIOUS       NaN       EUTHANIZED
# 3  TREATABLE REHABILITABLE NON-CONTAGIOUS  ALLERGIC         ADOPTION
# 4    UNHEALTHY UNTREATABLE NON-CONTAGIOUS       NaN  DEAD ON ARRIVAL
#
#   Additional Information
# 0                ADOPTED
# 1                    NaN
# 2                    NaN
# 3          VOMIT 5X 9/20
# 4                    NaN

# %%
#Calculate time between intake and outcome
Length_of_Stay = []
for x in range(0, len(clean_df)):
    Length_of_Stay.append(clean_df['Outcome Date'][x] - clean_df['Intake Date'][x])

# %%
type(Length_of_Stay)
# Out:
# list

# %%
len(Length_of_Stay)
# Out:
# 211216

# %%
clean_df['Length of Stay'] = Length_of_Stay
clean_df.head()
# Out:
# C:\Users\slapp\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#   Animal Id Animal Type   Animal Breed     Animal Origin Census Tract  \
# 0  A0000575         CAT    DOMESTIC SH  OVER THE COUNTER            W
# 1  A0008962         DOG  LABRADOR RETR             FIELD        75218
# 2  A0121376         DOG  GERM SHEPHERD             FIELD          39A
# 3  A0129114         CAT    DOMESTIC SH  OVER THE COUNTER        75243
# 4  A0157434         DOG     ROTTWEILER             FIELD          38G
#
#   Council District   Chip Status Intake Date Outcome Date  \
# 0                W  SCAN NO CHIP  2014-10-02   2014-10-12
# 1               18  SCAN NO CHIP  2015-09-24   2015-10-04
# 2               9A     SCAN CHIP  2015-05-01   2015-05-03
# 3               43     SCAN CHIP  2015-09-19   2015-10-26
# 4               8G  SCAN NO CHIP  2014-12-03   2014-12-04
#
#                          Intake Condition  \
# 0  TREATABLE REHABILITABLE NON-CONTAGIOUS
# 1  TREATABLE REHABILITABLE NON-CONTAGIOUS
# 2     TREATABLE MANAGEABLE NON-CONTAGIOUS
# 3  TREATABLE REHABILITABLE NON-CONTAGIOUS
# 4    UNHEALTHY UNTREATABLE NON-CONTAGIOUS
#
#                         Outcome Condition    Reason     Outcome Type  \
# 0  TREATABLE REHABILITABLE NON-CONTAGIOUS       NaN         ADOPTION
# 1     TREATABLE MANAGEABLE NON-CONTAGIOUS       NaN       EUTHANIZED
# 2     TREATABLE MANAGEABLE NON-CONTAGIOUS       NaN       EUTHANIZED
# 3  TREATABLE REHABILITABLE NON-CONTAGIOUS  ALLERGIC         ADOPTION
# 4    UNHEALTHY UNTREATABLE NON-CONTAGIOUS       NaN  DEAD ON ARRIVAL
#
#   Additional Information Length of Stay
# 0                ADOPTED        10 days
# 1                    NaN        10 days
# 2                    NaN         2 days
# 3          VOMIT 5X 9/20        37 days
# 4                    NaN         1 days

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211216 entries, 0 to 211215
# Data columns (total 15 columns):
# Animal Id                 211216 non-null object
# Animal Type               211215 non-null object
# Animal Breed              211215 non-null object
# Animal Origin             207986 non-null object
# Census Tract              202431 non-null object
# Council District          202431 non-null object
# Chip Status               208083 non-null object
# Intake Date               211216 non-null datetime64[ns]
# Outcome Date              210594 non-null datetime64[ns]
# Intake Condition          211216 non-null object
# Outcome Condition         204342 non-null object
# Reason                    79876 non-null object
# Outcome Type              211216 non-null object
# Additional Information    103130 non-null object
# Length of Stay            210594 non-null timedelta64[ns]
# dtypes: datetime64[ns](2), object(12), timedelta64[ns](1)
# memory usage: 24.2+ MB

# %%
quartiles = clean_df['Length of Stay'].quantile([.25,.5,.75])
lowerq = 0
upperq = 8
iqr = upperq-lowerq

print(f"The lower quartile of temperatures is: {lowerq}")
print(f"The upper quartile of temperatures is: {upperq}")
print(f"The interquartile range of temperatures is: {iqr}")
print(f"The the median of temperatures is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of temperatures is: 0
# The upper quartile of temperatures is: 8
# The interquartile range of temperatures is: 8
# The the median of temperatures is: 345600000000000
# Values below -12.0 could be outliers.
# Values above 20.0 could be outliers.

# %%
clean_df.describe()
# Out:
#                 Length of Stay
# count                   210594
# mean    6 days 22:52:06.858315
# std    12 days 05:34:58.383025
# min            0 days 00:00:00
# 25%            0 days 00:00:00
# 50%            4 days 00:00:00
# 75%            8 days 00:00:00
# max          663 days 00:00:00

# %%
clean_df = clean_df.loc[clean_df['Length of Stay'] < "60 days"]

# %%
clean_df.describe()
# Out:
#                Length of Stay
# count                  209103
# mean   6 days 07:23:02.390496
# std    8 days 14:06:30.238256
# min           0 days 00:00:00
# 25%           0 days 00:00:00
# 50%           4 days 00:00:00
# 75%           8 days 00:00:00
# max          59 days 00:00:00

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 209103 entries, 0 to 211215
# Data columns (total 15 columns):
# Animal Id                 209103 non-null object
# Animal Type               209102 non-null object
# Animal Breed              209102 non-null object
# Animal Origin             206623 non-null object
# Census Tract              201161 non-null object
# Council District          201161 non-null object
# Chip Status               206714 non-null object
# Intake Date               209103 non-null datetime64[ns]
# Outcome Date              209103 non-null datetime64[ns]
# Intake Condition          209103 non-null object
# Outcome Condition         203540 non-null object
# Reason                    79406 non-null object
# Outcome Type              209103 non-null object
# Additional Information    102684 non-null object
# Length of Stay            209103 non-null timedelta64[ns]
# dtypes: datetime64[ns](2), object(12), timedelta64[ns](1)
# memory usage: 25.5+ MB

# %%
cleaner_df = clean_df[clean_df['Intake Condition'] != "DEAD"]
cleaner_df = cleaner_df[cleaner_df['Intake Condition'] != "FATAL"]
cleaner_df = cleaner_df[cleaner_df['Intake Condition'] != "DECEASED"]
cleaner_df = cleaner_df[cleaner_df['Intake Condition'] != "UNHEALTHY UNTREATABLE CONTAGIOUS"]

cleaner_df['Intake Condition'].value_counts()
# Out:
# TREATABLE REHABILITABLE NON-CONTAGIOUS    125162
# UNHEALTHY UNTREATABLE NON-CONTAGIOUS       21364
# APP WNL                                    18723
# TREATABLE MANAGEABLE NON-CONTAGIOUS        17087
# HEALTHY                                    11883
# NORMAL                                      2389
# TREATABLE REHABILITABLE CONTAGIOUS          1762
# APP SICK                                    1446
# APP INJ                                     1333
# UNKNOWN                                     1201
# UNDERAGE                                     896
# TREATABLE MANAGEABLE CONTAGIOUS              725
# CRITICAL                                     320
# Name: Intake Condition, dtype: int64

# %%
cleaner_df['Outcome Type'].value_counts()
# Out:
# ADOPTION             65435
# EUTHANIZED           43526
# TRANSFER             37861
# RETURNED TO OWNER    32899
# FOSTER                9437
# WILDLIFE              2483
# TREATMENT             2462
# LOST EXP              1852
# DIED                  1751
# FOUND REPORT          1099
# FOUND EXP              540
# MISSING                173
# OTHER                   14
# Name: Outcome Type, dtype: int64

# %%
cleaner_df = cleaner_df[cleaner_df['Outcome Type'] != "DEAD ON ARRIVAL"]
cleaner_df = cleaner_df[cleaner_df['Outcome Type'] != "LOST REPORT"]

# %%
len(cleaner_df)
# Out:
# 199532

# %%
dog_df = clean_df.loc[clean_df['Animal Type'] == "DOG"]
cat_df = clean_df.loc[clean_df['Animal Type'] == "CAT"]
len(dog_df)
# Out:
# 149971

# %%
len(cat_df)
# Out:
# 50593

# %%
cleaner_df.to_csv('../Resources/combined_shelter_data.csv')
cat_df.to_csv('../Resources/cat.csv')
dog_df.to_csv('../Resources/dog.csv')
